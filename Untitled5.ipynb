# %% [markdown]
# <a href="https://colab.research.google.com/github/kavya07092007/SD_kavya_0079/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l=[1,2,3,4,4,"sudh","kumar",324,34.456,"abc"]

# %%
x=input()
if x==(x[::-1]):
    print("palindrome")
else:
    print("not palindrome")
# Out:
# enter the number121
# palindrome

# %%
l1_num
# Out:
# [1, 2, 3, 4, 4, 324, 34.456]

# %%
l2_str
# Out:
# ['sudh', 'kumar', 'abc']

# %%
x=int(input("enter the number:"))
temp=x
reverse=0
while x>0:
  digit=x%10
  reverse=(reverse*10)+digit
  x=x//10
if temp==reverse:
  print("palindrome")
else:
  print("not palindrome")
# Out:
# enter the number:123
# not palindrome

# %%
l=[5,9,6,7,8,9,2,3,18,19]

# %%
dic={"name": "kavya","age":19,"number":4567}

# %%
key=[]
value=[]
for item in dic.items():
  key.append(item[0]),value.append(item[1])

  print("keys:", key)
  print("values",value)
# Out:
# keys: ['name']
# values ['kavya']
# keys: ['name', 'age']
# values ['kavya', 19]
# keys: ['name', 'age', 'number']
# values ['kavya', 19, 4567]
