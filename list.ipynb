# %% [markdown]
# <a href="https://colab.research.google.com/github/kavya07092007/SD_kavya_0079/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list=["kavya",True,34,36.7,False,5+4j]
# Out:
# ['kavya', True]

# %%
list[0:6:2]
# Out:
# ['kavya', 34, False]

# %%
list[5].real
# Out:
# 5.0

# %%
list[::2]
# Out:
# ['kavya', 34, False]

# %%
list[-1]
# Out:
# (5+4j)

# %%
list[::-1]
# Out:
# [(5+4j), False, 36.7, 34, True, 'kavya']

# %%
list[-1:-3:-2]
# Out:
# [(5+4j)]

# %%
list[1:3:-2]
# Out:
# []

# %%
l=[1,345,45,"sudh",True,(5+7j),345.456]

# %%
l[0:8:6]
# Out:
# [1, 345.456]

# %%
l.append(2)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, '2', '2', '2', 2]

# %%
l.pop(2)
# Out:
# 'sudh'

# %%
l
# Out:
# [1, 345, True, (5+7j), 345.456, '2', '2', '2', 2, 2]

# %%
l.pop(7)
# Out:
# 2

# %%
l
# Out:
# [1, 345, True, (5+7j), 345.456, '2', '2', 2]

# %%
s="my name is kavya arya "

# %%
l
# Out:
# [1, 345, True, (5+7j), 345.456, '2', '2', 2]

# %%
len=[32,90,"harry",89.6]

# %%
l1=["harry",32,78.9,True,"india"]

# %%
l1.append(2)

# %%
l1
# Out:
# ['harry', 32, 78.9, True, 'india', 2, 2]

# %%
l1.pop(4)
# Out:
# 2

# %%
l1[4][0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1509/3622152879.py in <cell line: 0>()
# ----> 1 l1[4][0:2]
#
# TypeError: 'int' object is not subscriptable
