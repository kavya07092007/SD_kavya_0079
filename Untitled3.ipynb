# %% [markdown]
# <a href="https://colab.research.google.com/github/kavya07092007/SD_kavya_0079/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l=[1,345,45,"sudh",True,5+7j,345.456]

# %%
l[5].real
# Out:
# 5.0

# %%
l[0:5:4]
# Out:
# [1, True]

# %%
type(l)
# Out:
# list

# %%
l[0]
# Out:
# 1

# %%
l[6]
# Out:
# 345.456

# %%
l[4]
# Out:
# True

# %%
l[-1:-5:-2]
# Out:
# [345.456, True]

# %%
l[-1]
# Out:
# 345.456

# %%
s="maritimeexpertise"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_446/1140923193.py in <cell line: 0>()
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s)+l
# Out:
# ['m',
#  'a',
#  'r',
#  'i',
#  't',
#  'i',
#  'm',
#  'e',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  't',
#  'i',
#  's',
#  'e',
#  1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456]

# %%
type(l[3])
# Out:
# str

# %%
l[3][0:2]
# Out:
# 'su'

# %%
l[4]
# Out:
# True

# %%
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
l1=[3,4,5]

# %%
l+l1
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 3, 4, 5]

# %%
l*3
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456]

# %%
len(l)
# Out:
# 7

# %%
l.append(5)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 5]

# %%
s
# Out:
# 'maritimeexpertise'

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 5]

# %%
l1
# Out:
# [3, 4, 5]

# %%
l.extend("sudh")

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 5, 's', 'u', 'd', 'h']

# %%
l1.insert(1,"sudh")

# %%
l1
# Out:
# [3, 'sudh', 4, 5]

# %%
l1.insert(2,[2,3,4])

# %%
l1
# Out:
# [45, 3, 'sudh', [2, 3, 4], 4]

# %%
l1.insert(0,45)

# %%
l1
# Out:
# [45, 3, 'sudh', [2, 3, 4], 4, 5]

# %%
l1.pop()
# Out:
# 5

# %%
l1.insert(-1,45)

# %%
l1
# Out:
# [45, 3, 'sudh', [2, 3, 4], 45, 4]

# %%
l1.pop(3)
# Out:
# [2, 3, 4]

# %%
l1.remove(3)

# %%
l1
# Out:
# [45, 'sudh', 45, 4]

# %%
l1.remove(234)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_446/2189347925.py in <cell line: 0>()
# ----> 1 l1.remove(234)
#
# ValueError: list.remove(x): x not in list

# %%
l1.remove(4)

# %%
l1
# Out:
# [45, 'sudh', 45]

# %%
l1.reverse()

# %%
l1
# Out:
# [45, 'sudh', 45]

# %%
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_446/2406146923.py in <cell line: 0>()
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l2=[45,23,90,0,3,4,5,6,7,8,9]

# %%
l2.sort()

# %%
l2
# Out:
# [0, 3, 4, 5, 6, 7, 8, 9, 23, 45, 90]

# %%
l5=[23,56,54,32,45]

# %%
l5[0]=30

# %%
l5
# Out:
# [30, 56, 54, 32, 45]

# %%
s.replace('s','a')
# Out:
# 'maritimeexpertiae'

# %%
t=(2,3,4,5,"sudh",45.56,False,45+457j,[3,4,5])

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 9

# %%
t[0]
# Out:
# 2

# %%
t[-1]
# Out:
# [3, 4, 5]

# %%
t*3
# Out:
# (2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5],
#  2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5],
#  2,
#  3,
#  4,
#  5,
#  'sudh',
#  45.56,
#  False,
#  (45+457j),
#  [3, 4, 5])

# %%
s1={}

# %%
type(s1)
# Out:
# dict

# %%
s2={2,3,4,55,6}

# %%
type(s2)
# Out:
# set

# %%
s3={324,456,456,"sudh",45+45j,34.456,(3,4,5)}

# %%
s3
# Out:
# {(3, 4, 5), (45+45j), 324, 34.456, 456, 'sudh'}

# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d1={'key':"sudh"}

# %%
d1
# Out:
# {'key': 'sudh'}

# %%
d2={'name':"sudhanshu","email":"ss@gmail.com","number":334534}

# %%
d2
# Out:
# {'name': 'sudhanshu', 'email': 'ss@gmail.com', 'number': 334534}

# %%
d3={234:"sudh",'_wer':"kumar,True:24234"}

# %%
d3
# Out:
# {234: 'sudh', '_wer': 'kumar,True:24234'}

# %%
d3[234]
# Out:
# 'sudh'

# %%
d3[True]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_446/3513738043.py in <cell line: 0>()
# ----> 1 d3[True]
#
# KeyError: True
