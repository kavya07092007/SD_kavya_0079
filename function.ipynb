# %% [markdown]
# <a href="https://colab.research.google.com/github/kavya07092007/SD_kavya_0079/blob/main/function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a, b):
    return a + b
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number:"))
result = add(num1, num2)
print("Sum =", result)
# Out:
# Enter first number: 90
# Enter second number:57
# Sum = 147

# %%
def test1():
  return("this is my very very first function")

# %%
test1()
# Out:
# 'this is my very very first function'

# %%
test1() + "sudh"
# Out:
# 'this is my very very first functionsudh'

# %%
def test2():
  return"this is my very first return"

# %%
test2()
# Out:
# 'this is my very first return'

# %%
test2() + "sudh"
# Out:
# 'this is my very first returnsudh'

# %%
def test3() :
  return "sudh",23,345.56,[12,2,3,3]

# %%
test3()
# Out:
# ('sudh', 23, 345.56, [12, 2, 3, 3])

# %%
a,b,c,d = test3()

# %%
a
# Out:
# 'sudh'

# %%
b
# Out:
# 23

# %%
c
# Out:
# 345.56

# %%
d
# Out:
# [12, 2, 3, 3]

# %%
def test():
  a=5+6/7
  return a

# %%
test()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
  d=a+b/c
  return d

# %%
test5(4,5,6.78)
# Out:
# 4.737463126843657

# %%
def test6(a,b):
  return a+b

# %%
test6(4,5)
# Out:
# 9

# %%
def test7("sudh","kumar"):
  return "sudh"+"kumar"
# Out:
#   File "/tmp/ipykernel_510/3129466093.py", line 1
#     def test7("sudh","kumar"):
#               ^
# SyntaxError: invalid syntax

# %%
def testl1(*args):
  return args + [1,2,3,4]

# %%
type(testl1())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_510/4228719297.py in <cell line: 0>()
# ----> 1 type(testl1())
#
# /tmp/ipykernel_510/3333102344.py in testl1(*args)
#       1 def testl1(*args):
# ----> 2   return args + [1,2,3,4]
#       3
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
testl1(1,2),3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_510/3702980721.py in <cell line: 0>()
# ----> 1 testl1(1,2),3
#
# /tmp/ipykernel_510/3333102344.py in testl1(*args)
#       1 def testl1(*args):
# ----> 2   return args + [1,2,3,4]
#       3
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
 def testl2(1,2,34,4):
  return
# Out:
#   File "/tmp/ipykernel_510/1931752903.py", line 1
#     def testl2(1,2,34,4):
#                ^
# SyntaxError: invalid syntax

# %%
def testl4(c,d,a=23,b=1):
  return a,b,c,d

# %%
testl4(3,4)
# Out:
# (23, 1, 3, 4)

# %%
testl4(2,5,a=2342)
# Out:
# (2342, 1, 2, 5)

# %%
def testl5(**kwargs):
  return kwargs

# %%
testl5()
# Out:
# {}

# %%
testl5(a=[1,2,3,4],b="sudh",c=23.45)
# Out:
# {'a': [1, 2, 3, 4], 'b': 'sudh', 'c': 23.45}

# %%
def add(a,b):
  return a+b
def sub(a,b):
  return a-b
def mul(a,b):
  return a*b
def div(a,b):
  return a/b

# %%
account_number=(int(input()))
print("enter the pin:")
pin=(int(input()))
dic={"bank_balance":2000000,"account_number":12675345,"pin":1010}
if account_number==dic["account_number"] and pin==dic["pin"]:
  print("your card is valid")
print("1-bank balance")
print("2-withdrawal")
print("3-deposit")
print("4-exit")
option=int(input("enter the option:"))
if option==1:
  print("your bank balance is:",dic["bank_balance"])
elif option==2:
  amount=int(input("enter the amount:"))
  if amount>dic["bank_balance"]:
    print("insufficient balance")
  else:
    print("your remaining balance is:",dic["bank_balance"]-amount)
elif option==3:
  print("your remaining balance is:",dic["bank_balance"]+amount)
else:
  print("exit")
print("thanks! for using the services of bank")
